# %%
import numpy as np
from sklearn.linear_model import LinearRegression

# Data
X = np.array([1, 2, 3, 4, 5]).reshape(-1, 1)  # Hours studied
y = np.array([35, 40, 50, 55, 60])           # Marks

# Model
model = LinearRegression()
model.fit(X, y)

# Prediction
print("Predicted marks for 6 hours:", model.predict([[6]]))

# Parameters
print("Slope:", model.coef_)
print("Intercept:", model.intercept_)
# Out:
# Predicted marks for 6 hours: [67.5]
# Slope: [6.5]
# Intercept: 28.499999999999996
